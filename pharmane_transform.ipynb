# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitorhugofsousa/pharmaNE/blob/main/pharmane_transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Study case from Pharma Nordeste
# Transformations Notebook

# %%
#Importing libs and mounting drive
import pandas as pd
import numpy as np
import os
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

# %%
#Importing tables csv files
df_pharmacies = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/dim_farmacias_final.csv')
df_medicamentlst = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/lista_medicamentos_expandida.csv')
df_pharmacies_cap = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/dim_capacidade_farmacia.csv')
df_batchs = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/dim_lotes_validade.csv')
df_distribuition = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/distribuicao_medicamentos_completa.csv')
df_shipments = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/historico_remessas_2sem.csv')
df_logistical_occ = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/ocorrencias_logisticas.csv')
df_sales = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/tabela_vendas.csv')
df_clients = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/tabelas_pharma/dim_clientes.csv')

# %% [markdown]
# ## Transforming All the Data

# %%
df_pharmacies = pd.merge(df_pharmacies,df_pharmacies_cap, on='cod_farmacia', how='left')
df_pharmacies = df_pharmacies.drop(columns=['nome_farmacia_y','cidade_y','bairro_localizacao'])
df_pharmacies = df_pharmacies.rename(columns={'nome_farmacia_x': 'nome_farmacia', 'cidade_x': 'cidade'})
display(df_pharmacies)
# MERGING THE TABLES WHICH HAVE INFORMATION OF ALL THE PHARMACIES, THATS ONE OF OUR DIMENSION TABLES

# %%
df_sales = df_sales.drop_duplicates()
df_sales = df_sales.fillna('Não Informado')
display(df_sales)
# CLEANING DUPLICATED VALUES AND REPLACING EMPTY VALUES

# %%
  #We need to put attencion later to discover all the dates empty
df_shipments = df_shipments.drop(columns=['fabricante'])
display(df_shipments)

# %%
# DROPING UNESSESSARY COLUMNS AT MEDICAMENT DISTRIBUITION TABLE
df_distribuition = df_distribuition.drop(columns=['nome_farmacia', 'cidade', 'nome_medicamento', 'substancia_principal', 'apresentacao', 'dosagem', 'fabricante', 'categoria'])
display(df_distribuition)

# %%
# DROPING UNESSESSARY COLUMN AT LOGISTICAL OCCURRENCIES TABLE
df_logistical_occ = df_logistical_occ.drop(columns=['categoria_produto'])
display(df_logistical_occ)
